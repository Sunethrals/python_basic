# %%
class zomoto:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    restaruntname=["pista","pradise","raghavendra","aha","everygeen"]
    biryani=["chicken","mutton","panner","vegtable","mushrrom"]
    butternoon=["panner","cheese","butter"]
    friedrice=["egg","chicken","vegetable"]
    curry=["chicken","mutton","panner","kajhu"]
    fires=["fish","chicken"]
    italian=["soupes","rice"]
    chines=["nuddeles","manchuraya"]
    
    def __init__(self,restaruntname,biryani,butternon,friedrice,curry,fires,itlain,chines):
        self.restaruntname=restaruntname
        self.biryani=biryani
        self.butternoon=butternon
        self.friedrice=friedrice
        self.curry=curry
        self.fires=fires
        self.italian=itlain
        self.chines=chines
        
    restaruntname=["pista","pradise","raghavendra","aha","everygeen"]
    biryani=["chicken","mutton","panner","vegtable","mushrrom"]
    butternoon=["panner","cheese","butter"]
    friedrice=["egg","chicken","vegetable"]
    curry=["chicken","mutton","panner","kajhu"]
    fires=["fish","chicken"]
    italian=["soupes","rice"]
    chines=["nuddeles","manchuraya"]
    @classmethod
    def menu(cls):
        res=input("enter the restaruntname:")
        if res in restaruntname:
            print("sucuues")
        else:
            print("enter the resturant name")
zomoto.menu()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\M.Sunethra\Documents\GitHub\python\oopsconcept.ipynb\zomoto.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W0sZmlsZQ%3D%3D?line=36'>37</a>         else:
#      <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W0sZmlsZQ%3D%3D?line=37'>38</a>             print("enter the resturant name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W0sZmlsZQ%3D%3D?line=38'>39</a> zomoto.menu()
#
# c:\Users\M.Sunethra\Documents\GitHub\python\oopsconcept.ipynb\zomoto.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a> @classmethod
#      <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a> def menu(cls):
#      <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W0sZmlsZQ%3D%3D?line=33'>34</a>     res=input("enter the restaruntname:")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W0sZmlsZQ%3D%3D?line=34'>35</a>     if res in restaruntname:
#      <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a>         print("sucuues")
#      <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W0sZmlsZQ%3D%3D?line=36'>37</a>     else:
#
# NameError: name 'restaruntname' is not defined

# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    vbcount=0
    vrcount=0
    vtcount=0
    mcount=0
    

    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNOON\n4.BUGER\n5.EXIT"))
            # print(n)
            match n:
                
                case 1:
                    v={"biryani":100,"rothi":50,"tiffin":50,"meal":100}
                    vl=list(v)
                    print("veg",vl)
                    user=input("enter the order:")
                    if user in vl:
                        if user == vl[0]:
                            print(vl[0])
                            onlineorder.biryani()
                        if user == vl[1]:
                            print(vl[1])
                            onlineorder.rothi()
                        if user == vl[2]:
                            print(vl[2])
                            onlineorder.tiffin()
                        if user == vl[3]:
                            print(vl[3])
                            onlineorder.meal()
                    else:
                        print("order is not available")
                case 2:
                    nv={"chicken":100,"mutton":130,"fish":150}
                    print("nonveg",list(nv))
                    user=input("enter the order:")
                    if user in nv:
                        print("sucuees")
                    else:
                        print("order is not available")
                case 3:
                    bn={"butter":30,"panner":50,"cheese":30}
                    print("butternoon",list(bn))
                    user=input("enter the order:")
                    if user in bn:
                        print("sucuees")
                    else:
                        print("order is not available")
                case 4:
                    b={"chicken":100,"veg":80}
                    print("buger",list(b))
                    user=input("enter the order:")
                    if user in b:
                        print("sucuees")
                    else:
                        print("order is not available")
        else:
            print("enter correct pin number")
    @classmethod
    def biryani(cls):
        onlineorder.vbcount+=1 
        print(onlineorder.vbcount)
    @classmethod
    def rothi(cls):
        onlineorder.vrcount+=1 
        print(onlineorder.vrcount)
    @classmethod
    def tiffin(cls):
        onlineorder.vtcount+=1 
        print(onlineorder.vtcount)
    @classmethod
    def meal(cls):
        onlineorder.mcount+=1 
        print(onlineorder.mcount)
    # @classmethod
    # def cart(cls):
onlineorder.login()
# Out:
# enter correct pin number

# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    vbcount=0
    vrcount=0
    vtcount=0
    mcount=0
    

    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNOON\n4.BUGER\n5.EXIT"))
            # print(n)
            match n:
                
                case 1:
                    v={"biryani":100,"rothi":50,"tiffin":50,"meal":100}
                    # vl=list(v)
                    # print("veg",vl)
                    # if user in vl:
                    return onlineorder.veg()
                    # user=input("enter the order:")
                    # if user in vl:
                    #     if user == vl[0]:
                    #         print(vl[0])
                    #         onlineorder.biryani()
                    #     if user == vl[1]:
                    #         print(vl[1])
                    #         onlineorder.rothi()
                    #     if user == vl[2]:
                    #         print(vl[2])
                    #         onlineorder.tiffin()
                    #     if user == vl[3]:
                    #         print(vl[3])
                    #         onlineorder.meal()
                    # else:
                    #     print("order is not available")
                case 2:
                    nv={"chicken":100,"mutton":130,"fish":150}
                    print("nonveg",list(nv))
                    user=input("enter the order:")
                    if user in nv:
                        print("sucuees")
                    else:
                        print("order is not available")
                case 3:
                    bn={"butter":30,"panner":50,"cheese":30}
                    print("butternoon",list(bn))
                    user=input("enter the order:")
                    if user in bn:
                        print("sucuees")
                    else:
                        print("order is not available")
                case 4:
                    b={"chicken":100,"veg":80}
                    print("buger",list(b))
                    user=input("enter the order:")
                    if user in b:
                        print("sucuees")
                    else:
                        print("order is not available")
                case _:
                    return
            return
        else:
            print("enter correct pin number")

    @classmethod
    def veg(cls):
        user=int(input("enter the order:\n1.biryani\n2.rothi\n3.tiffin\n4.meal"))
        match user:
            case 1:
                # print(vl[0])
                onlineorder.biryani()
            case 2:
                # print(vl[1])
                onlineorder.rothi()
            case 3:
                # print(vl[2])
                onlineorder.tiffin()
            case 4:
                # print(vl[3],"hhh")
                onlineorder.meal()
            case _:
                return
        return onlineorder.veg()
                    
    @classmethod
    def biryani(cls):
        onlineorder.vbcount+=1 
        print("biryani",onlineorder.vbcount)
    @classmethod
    def rothi(cls):
        onlineorder.vrcount+=1 
        print("rothi",onlineorder.vrcount)
    @classmethod
    def tiffin(cls):
        onlineorder.vtcount+=1 
        print("tiffin",onlineorder.vtcount)
    @classmethod
    def meal(cls):
        onlineorder.mcount+=1 
        print("meal",onlineorder.mcount)
    # @classmethod
    # def cart(cls):
onlineorder.login()
# Out:
# biryani 1
# rothi 1
# tiffin 1

# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    vbcount=0
    vrcount=0
    vtcount=0
    mcount=0
    nvccount=0
    nvmcount=0
    nvfcount=0
    bbcount=0
    bpcount=0
    bccount=0
    bnvcount=0
    bvcount=0
    # cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNOON\n4.BUGER\n5.EXIT"))
            match n:
                case 1:
                    v={"biryani":100,"rothi":50,"tiffin":50,"meal":100}
                    return onlineorder.veg()
                case 2:
                    nv={"chicken":100,"mutton":130,"fish":150}
                    return onlineorder.nonveg()
                case 3:
                    bn={"butter":30,"panner":50,"cheese":30}
                    return onlineorder.butternoon()
                case 4:
                    b={"nonveg":100,"veg":80}
                    return onlineorder.buger()
                case _:
                    return
        else:
            print("enter correct pin number")

    @classmethod
    def veg(cls):
        user=int(input("enter the order:\n1.biryani\n2.rothi\n3.tiffin\n4.meal\n5.exit"))
        match user:
            case 1:
                onlineorder.biryani()
            case 2:
                onlineorder.rothi()
            case 3:
                onlineorder.tiffin()
            case 4:
                onlineorder.meal()
            case _:
                return
        return onlineorder.veg()
                 
    @classmethod
    def biryani(cls):
        onlineorder.vbcount+=1 
        print("biryani",onlineorder.vbcount)
    @classmethod
    def rothi(cls):
        onlineorder.vrcount+=1 
        print("rothi",onlineorder.vrcount)
    @classmethod
    def tiffin(cls):
        onlineorder.vtcount+=1 
        print("tiffin",onlineorder.vtcount)
    @classmethod
    def meal(cls):
        onlineorder.mcount+=1 
        print("meal",onlineorder.mcount)
    @classmethod
    def nonveg(cls):
        user=int(input("enter the order:\n1.chicken\n2.mutton\n3.fish\n4.exit"))
        match user:
            case 1:
                onlineorder.chicken()
            case 2:
                onlineorder.mutton()
            case 3:
                onlineorder.fish()
            case _:
                return
        return onlineorder.nonveg()
    @classmethod
    def chicken(cls):
        onlineorder.nvccount+=1
        print("chicken",onlineorder.nvccount)
    @classmethod
    def mutton(cls):
        onlineorder.nvmcount+=1
        print("mutton",onlineorder.nvmcount)
    @classmethod
    def fish(cls):
        onlineorder.nvfcount+=1
        print("fish",onlineorder.nvfcount)
    @classmethod
    def butternoon(cls):
        user=int(input("enter the order:\n1.butter\n2.paneer\n3.cheese\n4.exit"))
        match user:
            case 1:
                onlineorder.butter()
            case 2:
                onlineorder.panner()
            case 3:
                onlineorder.cheese()
            case _:
                return
        return onlineorder.butternoon()
    @classmethod
    def butter(cls):
        onlineorder.bbcount+=1
        print("butter",onlineorder.bbcount)
    @classmethod
    def panner(cls):
        onlineorder.bpcount+=1
        print("paneer",onlineorder.bpcount)
    @classmethod
    def cheese(cls):
        onlineorder.bccount+=1
        print("cheese",onlineorder.bccount)
    @classmethod
    def buger(cls):
        user=int(input("enter the order:\n1.nonveg\n2.veg\n3.exit"))
        match user:
            case 1:
                onlineorder.nonveg()
            case 2:
                onlineorder.vegb()
            case _:
                return
        return onlineorder.buger()
    @classmethod
    def nonvegb(cls):
        onlineorder.bnvcount+=1
        print("nonveg",onlineorder.bnvcount)
    @classmethod
    def vegb(cls):
        onlineorder.bvcount+=1
        print("veg",onlineorder.bvcount)
    cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
    
    # @classmethod
    # def cart(cls):   
# onlineorder.cart_details
# print(onlineorder.cart_details)

    onlineorder.login()

# onlineorder.cart_details
# @classmethod
# v={"biryani":100,"rothi":50,"tiffin":50,"meal":100}
# def cart(st):
#     print(st)
#     for i in st:
#         if st[i]>0:
#             print(i,st[i],st[i]*v[i])
# cart(onlineorder.cart_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\M.Sunethra\Documents\GitHub\python\oopsconcept.ipynb\zomoto.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> class onlineorder:
#       <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     name="sunethra"
#       <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>     phone=7396929629
#
# c:\Users\M.Sunethra\Documents\GitHub\python\oopsconcept.ipynb\zomoto.ipynb Cell 4 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=140'>141</a>         onlineorder.bvcount+=1
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=141'>142</a>         print("veg",onlineorder.bvcount)
# --> <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=142'>143</a>     cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=144'>145</a>     # @classmethod
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=145'>146</a>     # def cart(cls):
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=146'>147</a> # onlineorder.cart_details
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=147'>148</a> # print(onlineorder.cart_details)
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W4sZmlsZQ%3D%3D?line=149'>150</a>     onlineorder.login()
#
# NameError: name 'onlineorder' is not defined

# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    vbcount=0
    vrcount=0
    vtcount=0
    mcount=0
    nvccount=0
    nvmcount=0
    nvfcount=0
    bbcount=0
    bpcount=0
    bccount=0
    bnvcount=0
    bvcount=0
    # cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNOON\n4.BUGER\n5.EXIT"))
            match n:
                case 1:
                    return onlineorder.veg()
                case 2:
                    return onlineorder.nonveg()
                case 3:
                    return onlineorder.butternoon()
                case 4:
                    return onlineorder.buger()
                case _:
                    return
        else:
            print("enter correct pin number")

    @classmethod
    def veg(cls):
        user=int(input("enter the order:\n1.biryani\n2.rothi\n3.tiffin\n4.meal\n5.exit"))
        match user:
            case 1:
                onlineorder.biryani()
            case 2:
                onlineorder.rothi()
            case 3:
                onlineorder.tiffin()
            case 4:
                onlineorder.meal()
            case _:
                return
        return onlineorder.veg()
                 
    @classmethod
    def biryani(cls):
        onlineorder.vbcount+=1 
        print("biryani",onlineorder.vbcount)
    @classmethod
    def rothi(cls):
        onlineorder.vrcount+=1 
        print("rothi",onlineorder.vrcount)
    @classmethod
    def tiffin(cls):
        onlineorder.vtcount+=1 
        print("tiffin",onlineorder.vtcount)
    @classmethod
    def meal(cls):
        onlineorder.mcount+=1 
        print("meal",onlineorder.mcount)
    @classmethod
    def nonveg(cls):
        user=int(input("enter the order:\n1.chicken\n2.mutton\n3.fish\n4.exit"))
        match user:
            case 1:
                onlineorder.chicken()
            case 2:
                onlineorder.mutton()
            case 3:
                onlineorder.fish()
            case _:
                return
        return onlineorder.nonveg()
    @classmethod
    def chicken(cls):
        onlineorder.nvccount+=1
        print("chicken",onlineorder.nvccount)
    @classmethod
    def mutton(cls):
        onlineorder.nvmcount+=1
        print("mutton",onlineorder.nvmcount)
    @classmethod
    def fish(cls):
        onlineorder.nvfcount+=1
        print("fish",onlineorder.nvfcount)
    @classmethod
    def butternoon(cls):
        user=int(input("enter the order:\n1.butter\n2.paneer\n3.cheese\n4.exit"))
        match user:
            case 1:
                onlineorder.butter()
            case 2:
                onlineorder.panner()
            case 3:
                onlineorder.cheese()
            case _:
                return
        return onlineorder.butternoon()
    @classmethod
    def butter(cls):
        onlineorder.bbcount+=1
        print("butter",onlineorder.bbcount)
    @classmethod
    def panner(cls):
        onlineorder.bpcount+=1
        print("paneer",onlineorder.bpcount)
    @classmethod
    def cheese(cls):
        onlineorder.bccount+=1
        print("cheese",onlineorder.bccount)
    @classmethod
    def buger(cls):
        user=int(input("enter the order:\n1.nonveg\n2.veg\n3.exit"))
        match user:
            case 1:
                onlineorder.nonveg()
            case 2:
                onlineorder.vegb()
            case _:
                return
        return onlineorder.buger()
    @classmethod
    def nonvegb(cls):
        onlineorder.bnvcount+=1
        print("nonveg",onlineorder.bnvcount)
    @classmethod
    def vegb(cls):
        onlineorder.bvcount+=1
        print("veg",onlineorder.bvcount)
    cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
onlineorder.login()
v={"biryani":100,"rothi":50,"tiffin":50,"meal":100}
nv={"chicken":100,"mutton":130,"fish":150}
bn={"butter":30,"panner":50,"cheese":30}
b={"nonveg":100,"veg":80}
def cart(st):
    print(st)
    total=0
    for i in st:
        if st[i]>0:
            if i in v:
                print(i,st[i]*v[i])
                total+=st[i]*v[i]
            if i in nv:
                print(i,st[i],st[i]*nv[i])
                total+=st[i]*nv[i]
            if i in bn:
                print(i,st[i],st[i]*bn[i])
                total+=st[i]*bn[i]
            if i in b:
                print(i,st[i],st[i]*b[i])
                total+=st[i]*b[i]
    print("total amount:",total)
cart(onlineorder.cart_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\M.Sunethra\Documents\GitHub\python\oopsconcept.ipynb\zomoto.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> class onlineorder:
#       <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     name="sunethra"
#       <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     phone=7396929629
#
# c:\Users\M.Sunethra\Documents\GitHub\python\oopsconcept.ipynb\zomoto.ipynb Cell 5 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=136'>137</a>     onlineorder.bvcount+=1
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=137'>138</a>     print("veg",onlineorder.bvcount)
# --> <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=138'>139</a> cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
#
# NameError: name 'onlineorder' is not defined

# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    vbcount=0
    vrcount=0
    vtcount=0
    mcount=0
    nvccount=0
    nvmcount=0
    nvfcount=0
    bbcount=0
    bpcount=0
    bccount=0
    bnvcount=0
    bvcount=0
    # cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNOON\n4.BUGER\n5.EXIT"))
            match n:
                case 1:
                    return onlineorder.veg()
                case 2:
                    return onlineorder.nonveg()
                case 3:
                    return onlineorder.butternoon()
                case 4:
                    return onlineorder.buger()
                case _:
                    return
        else:
            print("enter correct pin number")

    @classmethod
    def veg(cls):
        user=int(input("enter the order:\n1.biryani\n2.rothi\n3.tiffin\n4.meal\n5.exit"))
        match user:
            case 1:
                onlineorder.biryani()
            case 2:
                onlineorder.rothi()
            case 3:
                onlineorder.tiffin()
            case 4:
                onlineorder.meal()
            case _:
                return
        return onlineorder.veg()
                 
    @classmethod
    def biryani(cls):
        onlineorder.vbcount+=1 
        print("biryani",onlineorder.vbcount)
    @classmethod
    def rothi(cls):
        onlineorder.vrcount+=1 
        print("rothi",onlineorder.vrcount)
    @classmethod
    def tiffin(cls):
        onlineorder.vtcount+=1 
        print("tiffin",onlineorder.vtcount)
    @classmethod
    def meal(cls):
        onlineorder.mcount+=1 
        print("meal",onlineorder.mcount)
    @classmethod
    def nonveg(cls):
        user=int(input("enter the order:\n1.chicken\n2.mutton\n3.fish\n4.exit"))
        match user:
            case 1:
                onlineorder.chicken()
            case 2:
                onlineorder.mutton()
            case 3:
                onlineorder.fish()
            case _:
                return
        return onlineorder.nonveg()
    @classmethod
    def chicken(cls):
        onlineorder.nvccount+=1
        print("chicken",onlineorder.nvccount)
    @classmethod
    def mutton(cls):
        onlineorder.nvmcount+=1
        print("mutton",onlineorder.nvmcount)
    @classmethod
    def fish(cls):
        onlineorder.nvfcount+=1
        print("fish",onlineorder.nvfcount)
    @classmethod
    def butternoon(cls):
        user=int(input("enter the order:\n1.butter\n2.paneer\n3.cheese\n4.exit"))
        match user:
            case 1:
                onlineorder.butter()
            case 2:
                onlineorder.panner()
            case 3:
                onlineorder.cheese()
            case _:
                return
        return onlineorder.butternoon()
    @classmethod
    def butter(cls):
        onlineorder.bbcount+=1
        print("butter",onlineorder.bbcount)
    @classmethod
    def panner(cls):
        onlineorder.bpcount+=1
        print("paneer",onlineorder.bpcount)
    @classmethod
    def cheese(cls):
        onlineorder.bccount+=1
        print("cheese",onlineorder.bccount)
    @classmethod
    def buger(cls):
        user=int(input("enter the order:\n1.nonveg\n2.veg\n3.exit"))
        match user:
            case 1:
                onlineorder.nonveg()
            case 2:
                onlineorder.vegb()
            case _:
                return
        return onlineorder.buger()
    @classmethod
    def nonvegb(cls):
        onlineorder.bnvcount+=1
        print("nonveg",onlineorder.bnvcount)
    @classmethod
    def vegb(cls):
        onlineorder.bvcount+=1
        print("veg",onlineorder.bvcount)
    cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
onlineorder.login()
v={"biryani":100,"rothi":50,"tiffin":50,"meal":100}
nv={"chicken":100,"mutton":130,"fish":150}
bn={"butter":30,"panner":50,"cheese":30}
b={"nonveg":100,"veg":80}
def cart(st):
    print(st)
    total=0
    for i in st:
        if st[i]>0:
            if i in v:
                print(i,st[i]*v[i])
                total+=st[i]*v[i]
            if i in nv:
                print(i,st[i],st[i]*nv[i])
                total+=st[i]*nv[i]
            if i in bn:
                print(i,st[i],st[i]*bn[i])
                total+=st[i]*bn[i]
            if i in b:
                print(i,st[i],st[i]*b[i])
                total+=st[i]*b[i]
    print("total amount:",total)
cart(onlineorder.cart_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\M.Sunethra\Documents\GitHub\python\oopsconcept.ipynb\zomoto.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> class onlineorder:
#       <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     name="sunethra"
#       <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     phone=7396929629
#
# c:\Users\M.Sunethra\Documents\GitHub\python\oopsconcept.ipynb\zomoto.ipynb Cell 6 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=136'>137</a>     onlineorder.bvcount+=1
#     <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=137'>138</a>     print("veg",onlineorder.bvcount)
# --> <a href='vscode-notebook-cell:/c%3A/Users/M.Sunethra/Documents/GitHub/python/oopsconcept.ipynb/zomoto.ipynb#W5sZmlsZQ%3D%3D?line=138'>139</a> cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
#
# NameError: name 'onlineorder' is not defined
