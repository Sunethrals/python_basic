# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    vbcount=0
    vrcount=0
    vtcount=0
    mcount=0
    nvccount=0
    nvmcount=0
    nvfcount=0
    bbcount=0
    bpcount=0
    bccount=0
    bnvcount=0
    bvcount=0
    # cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNOON\n4.BUGER\n5.EXIT"))
            match n:
                case 1:
                    return onlineorder.veg()
                case 2:
                    return onlineorder.nonveg()
                case 3:
                    return onlineorder.butternoon()
                case 4:
                    return onlineorder.buger()
                case _:
                    return
        else:
            print("enter correct pin number")

    @classmethod
    def veg(cls):
        user=int(input("enter the order:\n1.biryani\n2.rothi\n3.tiffin\n4.meal\n5.exit"))
        match user:
            case 1:
                onlineorder.biryani()
            case 2:
                onlineorder.rothi()
            case 3:
                onlineorder.tiffin()
            case 4:
                onlineorder.meal()
            case _:
                return
        return onlineorder.veg()
                 
    @classmethod
    def biryani(cls):
        onlineorder.vbcount+=1 
        print("biryani",onlineorder.vbcount)
    @classmethod
    def rothi(cls):
        onlineorder.vrcount+=1 
        print("rothi",onlineorder.vrcount)
    @classmethod
    def tiffin(cls):
        onlineorder.vtcount+=1 
        print("tiffin",onlineorder.vtcount)
    @classmethod
    def meal(cls):
        onlineorder.mcount+=1 
        print("meal",onlineorder.mcount)
    @classmethod
    def nonveg(cls):
        user=int(input("enter the order:\n1.chicken\n2.mutton\n3.fish\n4.exit"))
        match user:
            case 1:
                onlineorder.chicken()
            case 2:
                onlineorder.mutton()
            case 3:
                onlineorder.fish()
            case _:
                return
        return onlineorder.nonveg()
    @classmethod
    def chicken(cls):
        onlineorder.nvccount+=1
        print("chicken",onlineorder.nvccount)
    @classmethod
    def mutton(cls):
        onlineorder.nvmcount+=1
        print("mutton",onlineorder.nvmcount)
    @classmethod
    def fish(cls):
        onlineorder.nvfcount+=1
        print("fish",onlineorder.nvfcount)
    @classmethod
    def butternoon(cls):
        user=int(input("enter the order:\n1.butter\n2.paneer\n3.cheese\n4.exit"))
        match user:
            case 1:
                onlineorder.butter()
            case 2:
                onlineorder.panner()
            case 3:
                onlineorder.cheese()
            case _:
                return
        return onlineorder.butternoon()
    @classmethod
    def butter(cls):
        onlineorder.bbcount+=1
        print("butter",onlineorder.bbcount)
    @classmethod
    def panner(cls):
        onlineorder.bpcount+=1
        print("paneer",onlineorder.bpcount)
    @classmethod
    def cheese(cls):
        onlineorder.bccount+=1
        print("cheese",onlineorder.bccount)
    @classmethod
    def buger(cls):
        user=int(input("enter the order:\n1.nonveg\n2.veg\n3.exit"))
        match user:
            case 1:
                onlineorder.nonveg()
            case 2:
                onlineorder.vegb()
            case _:
                return
        return onlineorder.buger()
    @classmethod
    def nonvegb(cls):
        onlineorder.bnvcount+=1
        print("nonveg",onlineorder.bnvcount)
    @classmethod
    def vegb(cls):
        onlineorder.bvcount+=1
        print("veg",onlineorder.bvcount)
onlineorder.login()
cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}

v={"biryani":100,"rothi":50,"tiffin":50,"meal":100}
nv={"chicken":100,"mutton":130,"fish":150}
bn={"butter":30,"panner":50,"cheese":30}
b={"nonveg":100,"veg":80}
def cart(st):
    print(st)
    total=0
    for i in st:
        if st[i]>0:
            if i in v:
                print(i,st[i]*v[i])
                total+=st[i]*v[i]
            if i in nv:
                print(i,st[i],st[i]*nv[i])
                total+=st[i]*nv[i]
            if i in bn:
                print(i,st[i],st[i]*bn[i])
                total+=st[i]*bn[i]
            if i in b:
                print(i,st[i],st[i]*b[i])
                total+=st[i]*b[i]
    print("total amount:",total)
cart(cart_details)
# Out:
# rothi 1
# biryani 1
# rothi 2
# {'biryani': 1, 'rothi': 2, 'tiffin': 0, 'meal': 0, 'chicken': 0, 'mutton': 0, 'fish': 0, 'butter': 0, 'panner': 0, 'cheese': 0, 'nonveg': 0, 'veg': 0}
# biryani 100
# rothi 100
# total amount: 200

# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    vbcount=0
    vrcount=0
    vtcount=0
    mcount=0
    nvccount=0
    nvmcount=0
    nvfcount=0
    bbcount=0
    bpcount=0
    bccount=0
    bnvcount=0
    bvcount=0
    # cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNON\n4.BUGER\n5.EXIT"))
            match n:
                case 1:
                    return onlineorder.veg()
                case 2:
                    return onlineorder.nonveg()
                case 3:
                    return onlineorder.butternoon()
                case 4:
                    return onlineorder.buger()
                case _:
                    return
        else:
            print("enter correct pin number")

    @classmethod
    def veg(cls):
        user=int(input("enter the order:\n1.biryani\n2.rothi\n3.tiffin\n4.meal\n5.nonveg\n6.butternoon\n7.buger\n8.exit"))
        match user:
            case 1:
                onlineorder.biryani()
            case 2:
                onlineorder.rothi()
            case 3:
                onlineorder.tiffin()
            case 4:
                onlineorder.meal()
            case 5:
                onlineorder.nonveg()
            case 6:
                onlineorder.butternoon()
            case 7:
                onlineorder.buger()
            case _:
                return
        return onlineorder.veg()
                 
    @classmethod
    def biryani(cls):
        onlineorder.vbcount+=1 
        print("biryani",onlineorder.vbcount)
    @classmethod
    def rothi(cls):
        onlineorder.vrcount+=1 
        print("rothi",onlineorder.vrcount)
    @classmethod
    def tiffin(cls):
        onlineorder.vtcount+=1 
        print("tiffin",onlineorder.vtcount)
    @classmethod
    def meal(cls):
        onlineorder.mcount+=1 
        print("meal",onlineorder.mcount)
    @classmethod
    def nonveg(cls):
        user=int(input("enter the order:\n1.chicken\n2.mutton\n3.fish\n4.veg\n5.butternoon\n6.buger\n7.exit"))
        match user:
            case 1:
                onlineorder.chicken()
            case 2:
                onlineorder.mutton()
            case 3:
                onlineorder.fish()
            case 4:
                onlineorder.veg()
            case 5:
                onlineorder.butternoon()
            case 6:
                onlineorder.buger()
            case _:
                return
        return onlineorder.nonveg()
    @classmethod
    def chicken(cls):
        onlineorder.nvccount+=1
        print("chicken",onlineorder.nvccount)
    @classmethod
    def mutton(cls):
        onlineorder.nvmcount+=1
        print("mutton",onlineorder.nvmcount)
    @classmethod
    def fish(cls):
        onlineorder.nvfcount+=1
        print("fish",onlineorder.nvfcount)
    @classmethod
    def butternoon(cls):
        user=int(input("enter the order:\n1.butter\n2.paneer\n3.cheese\n4.veg\n5.nonveg\n6.buger\n7.exit"))
        match user:
            case 1:
                onlineorder.butter()
            case 2:
                onlineorder.panner()
            case 3:
                onlineorder.cheese()
            case 4:
                onlineorder.veg()
            case 5:
                onlineorder.nonveg()
            case 6:
                onlineorder.buger()
            case _:
                return
        return onlineorder.butternoon()
    @classmethod
    def butter(cls):
        onlineorder.bbcount+=1
        print("butter",onlineorder.bbcount)
    @classmethod
    def panner(cls):
        onlineorder.bpcount+=1
        print("paneer",onlineorder.bpcount)
    @classmethod
    def cheese(cls):
        onlineorder.bccount+=1
        print("cheese",onlineorder.bccount)
    @classmethod
    def buger(cls):
        user=int(input("enter the order:\n1.nonvegbuger\n2.vegbuger\n3.veg\n4.nonveg\n5.butternoon\n6.exit"))
        match user:
            case 1:
                onlineorder.nonvegb()
            case 2:
                onlineorder.vegb()
            case 3:
                onlineorder.veg()
            case 4:
                onlineorder.nonveg()
            case 5:
                onlineorder.buger()
            case _:
                return
        return onlineorder.buger()
    @classmethod
    def nonvegb(cls):
        onlineorder.bnvcount+=1
        print("nonveg",onlineorder.bnvcount)
    @classmethod
    def vegb(cls):
        onlineorder.bvcount+=1
        print("veg",onlineorder.bvcount)
onlineorder.login()
cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}

v={"biryani":100,"rothi":50,"tiffin":50,"meal":100,"chicken":100,"mutton":130,"fish":150,"butter":30,"panner":50,"cheese":30,"nonveg":100,"veg":80}
# nv={"chicken":100,"mutton":130,"fish":150}
# bn={"butter":30,"panner":50,"cheese":30}
# b={"nonveg":100,"veg":80}
def cart(st):
    res={}
    for i in st:
        if st[i]>0:
            if i in v:
                res[i]=cart_details[i]
            # if i in nv:
            #     res[i]=cart_details[i]
            # if i in bn:
            #     res[i]=cart_details[i]
            # if i in b:
            #     res[i]=cart_details[i]
    print(res)
    total=0
    # res={}
    for i in st:
        if st[i]>0:
            if i in v:
                print(i,st[i]*v[i])
                total+=st[i]*v[i]
                # res[i]=cart_details[i]
            # if i in nv:
            #     print(i,st[i],st[i]*nv[i])
            #     total+=st[i]*nv[i]
            #     # res[i]=cart_details[i]
            # if i in bn:
            #     print(i,st[i],st[i]*bn[i])
            #     total+=st[i]*bn[i]
            #     # res[i]=cart_details[i]
            # if i in b:
            #     print(i,st[i],st[i]*b[i])
            #     total+=st[i]*b[i]
                
                # res[i]=cart_details[i]
    # print(res)
    print("total amount:",total)
cart(cart_details)
# Out:
# rothi 1
# tiffin 1
# biryani 1
# rothi 2
# chicken 1
# mutton 1
# {'biryani': 1, 'rothi': 2, 'tiffin': 1, 'chicken': 1, 'mutton': 1}
# biryani 100
# rothi 100
# tiffin 50
# chicken 100
# mutton 130
# total amount: 480

# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    vbcount=0
    vrcount=0
    vtcount=0
    mcount=0
    nvccount=0
    nvmcount=0
    nvfcount=0
    bbcount=0
    bpcount=0
    bccount=0
    bnvcount=0
    bvcount=0
    # cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}
    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNON\n4.BUGER\n5.EXIT"))
            match n:
                case 1:
                    return onlineorder.veg()
                case 2:
                    return onlineorder.nonveg()
                case 3:
                    return onlineorder.butternoon()
                case 4:
                    return onlineorder.buger()
                case _:
                    return
        else:
            print("enter correct pin number")

    @classmethod
    def veg(cls):
        user=int(input("enter the order:\n1.biryani\n2.rothi\n3.tiffin\n4.meal\n5.nonveg\n6.butternoon\n7.buger\n8.exit"))
        match user:
            case 1:
                onlineorder.biryani()
            case 2:
                onlineorder.rothi()
            case 3:
                onlineorder.tiffin()
            case 4:
                onlineorder.meal()
            case 5:
                onlineorder.nonveg()
            case 6:
                onlineorder.butternoon()
            case 7:
                onlineorder.buger()
            case _:
                return
        return onlineorder.veg()
                 
    @classmethod
    def biryani(cls):
        onlineorder.vbcount+=1 
        print("biryani",onlineorder.vbcount)
    @classmethod
    def rothi(cls):
        onlineorder.vrcount+=1 
        print("rothi",onlineorder.vrcount)
    @classmethod
    def tiffin(cls):
        onlineorder.vtcount+=1 
        print("tiffin",onlineorder.vtcount)
    @classmethod
    def meal(cls):
        onlineorder.mcount+=1 
        print("meal",onlineorder.mcount)
    @classmethod
    def nonveg(cls):
        user=int(input("enter the order:\n1.chicken\n2.mutton\n3.fish\n4.veg\n5.butternoon\n6.buger\n7.exit"))
        match user:
            case 1:
                onlineorder.chicken()
            case 2:
                onlineorder.mutton()
            case 3:
                onlineorder.fish()
            case 4:
                onlineorder.veg()
            case 5:
                onlineorder.butternoon()
            case 6:
                onlineorder.buger()
            case _:
                return
        return onlineorder.nonveg()
    @classmethod
    def chicken(cls):
        onlineorder.nvccount+=1
        print("chicken",onlineorder.nvccount)
    @classmethod
    def mutton(cls):
        onlineorder.nvmcount+=1
        print("mutton",onlineorder.nvmcount)
    @classmethod
    def fish(cls):
        onlineorder.nvfcount+=1
        print("fish",onlineorder.nvfcount)
    @classmethod
    def butternoon(cls):
        user=int(input("enter the order:\n1.butter\n2.paneer\n3.cheese\n4.veg\n5.nonveg\n6.buger\n7.exit"))
        match user:
            case 1:
                onlineorder.butter()
            case 2:
                onlineorder.panner()
            case 3:
                onlineorder.cheese()
            case 4:
                onlineorder.veg()
            case 5:
                onlineorder.nonveg()
            case 6:
                onlineorder.buger()
            case _:
                return
        return onlineorder.butternoon()
    @classmethod
    def butter(cls):
        onlineorder.bbcount+=1
        print("butter",onlineorder.bbcount)
    @classmethod
    def panner(cls):
        onlineorder.bpcount+=1
        print("paneer",onlineorder.bpcount)
    @classmethod
    def cheese(cls):
        onlineorder.bccount+=1
        print("cheese",onlineorder.bccount)
    @classmethod
    def buger(cls):
        user=int(input("enter the order:\n1.nonvegbuger\n2.vegbuger\n3.veg\n4.nonveg\n5.butternoon\n6.exit"))
        match user:
            case 1:
                onlineorder.nonvegb()
            case 2:
                onlineorder.vegb()
            case 3:
                onlineorder.veg()
            case 4:
                onlineorder.nonveg()
            case 5:
                onlineorder.buger()
            case _:
                return
        return onlineorder.butternoon()
    @classmethod
    def nonvegb(cls):
        onlineorder.bnvcount+=1
        print("nonveg",onlineorder.bnvcount)
    @classmethod
    def vegb(cls):
        onlineorder.bvcount+=1
        print("veg",onlineorder.bvcount)
onlineorder.login()
cart_details={'biryani':onlineorder.vbcount,"rothi":onlineorder.vrcount,"tiffin":onlineorder.vtcount,"meal":onlineorder.mcount,"chicken":onlineorder.nvccount,"mutton":onlineorder.nvmcount,"fish":onlineorder.nvfcount,"butter":onlineorder.bbcount,"panner":onlineorder.bpcount,"cheese":onlineorder.bccount,"nonveg":onlineorder.bnvcount,"veg":onlineorder.bvcount}

v={"biryani":100,"rothi":50,"tiffin":50,"meal":100,"chicken":100,"mutton":130,"fish":150,"butter":30,"panner":50,"cheese":30,"nonveg":100,"veg":80}
def cart(st):
    res={}
    for i in st:
        if st[i]>0:
            if i in v:
                res[i]=cart_details[i]

    print(res)
    total=0
    # res={}
    for i in st:
        if st[i]>0:
            if i in v:
                print(i,st[i]*v[i])
                total+=st[i]*v[i]
                # res[i]=cart_details[i]
    # print(res)
    print("total amount:",total)
cart(cart_details)
# Out:
# rothi 1
# biryani 1
# tiffin 1
# biryani 2
# {'biryani': 2, 'rothi': 1, 'tiffin': 1}
# biryani 200
# rothi 50
# tiffin 50
# total amount: 300

# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNON\n4.BUGER\n5.EXIT"))
            match n:
                case 1:
                    return onlineorder.veg()
                case 2:
                    return onlineorder.nonveg()
                case 3:
                    return onlineorder.butternoon()
                case 4:
                    return onlineorder.buger()
                case _:
                    return
        else:
            print("enter correct pin number")
    @classmethod
    def veg(cls):
        user=int(input("enter the order:\n1.biryani\n2.rothi\n3.tiffin\n4.meal\n8.exit"))
        match user:
            case 1:
                print('biryani')
                onlineorder.quanty()
            case 2:
                print('rothi')
                onlineorder.quanty()
            case 3:
                print('tiffin')
                onlineorder.quanty()
            case 4:
                print('meal')
                onlineorder.quanty()
            case 5:
                onlineorder.nonveg()
            case 6:
                onlineorder.butternoon()
            case 7:
                onlineorder.buger()
            case _:
                return
        return onlineorder.veg()
    @classmethod
    def nonveg(cls):
        user=int(input("enter the order:\n1.chicken\n2.mutton\n3.fish\n7.exit"))
        match user:
            case 1:
                print('chicken')
                onlineorder.quanty()
            case 2:
                print('mutton')
                onlineorder.quanty()
            case 3:
                print('fish')
                onlineorder.quanty()
            case 4:
                onlineorder.veg()
            case 5:
                onlineorder.butternoon()
            case 6:
                onlineorder.buger()
            case _:
                return
        return onlineorder.nonveg()  
    @classmethod
    def butternoon(cls):
        user=int(input("enter the order:\n1.butter\n2.paneer\n3.cheese\n7.exit"))
        match user:
            case 1:
                print("butter")
                onlineorder.quanty()
            case 2:
                print("panner")
                onlineorder.quanty()
            case 3:
                print("cheese")
                onlineorder.quanty()
            case 4:
                onlineorder.veg()
            case 5:
                onlineorder.nonveg()
            case 6:
                onlineorder.buger()
            case _:
                return
        return onlineorder.butternoon()
    @classmethod
    def buger(cls):
        user=int(input("enter the order:\n1.nonvegbuger\n2.vegbuger\n6.exit"))
        match user:
            case 1:
                print("nonvegbuger")
                onlineorder.quanty()
            case 2:
                print("vegbuger")
                onlineorder.quanty()
            case 3:
                onlineorder.veg()
            case 4:
                onlineorder.nonveg()
            case 5:
                onlineorder.butternoon()
            case _:
                return
        return onlineorder.buger()
    def quanty():
        q=int(input("enter no of quanties"))
        print(q)
onlineorder.login()
# Out:
# rothi
# 1
# chicken
# 3
# biryani
# 2

# %%
class onlineorder:
    name="sunethra"
    phone=7396929629
    location='hyderabad'
    pin=1234
    @classmethod
    def login(cls):
        pinlo=int(input("enter the pin:"))
        if pinlo==onlineorder.pin:
            n=int(input("CHOOSE THE OPTIONS:\n1.VEG\n2.NONVEG\n3.BUTTERNON\n4.BUGER\n5.EXIT"))
            match n:
                case 1:
                    return onlineorder.veg()
                case 2:
                    return onlineorder.nonveg()
                case 3:
                    return onlineorder.butternoon()
                case 4:
                    return onlineorder.buger()
                case _:
                    return
        else:
            print("enter correct pin number")
    @classmethod
    def veg(cls):
        user=int(input("enter the order:\n1.biryani\n2.rothi\n3.tiffin\n4.meal\n8.exit"))
        match user:
            case 1:
                print('biryani')
                onlineorder.quanty()
            case 2:
                print('rothi')
                onlineorder.quanty()
            case 3:
                print('tiffin')
                onlineorder.quanty()
            case 4:
                print('meal')
                onlineorder.quanty()
            case 5:
                onlineorder.nonveg()
            case 6:
                onlineorder.butternoon()
            case 7:
                onlineorder.buger()
            case _:
                return
        return onlineorder.veg()
    @classmethod
    def nonveg(cls):
        user=int(input("enter the order:\n1.chicken\n2.mutton\n3.fish\n7.exit"))
        match user:
            case 1:
                print('chicken')
                onlineorder.quanty()
            case 2:
                print('mutton')
                onlineorder.quanty()
            case 3:
                print('fish')
                onlineorder.quanty()
            case 4:
                onlineorder.veg()
            case 5:
                onlineorder.butternoon()
            case 6:
                onlineorder.buger()
            case _:
                return
        return onlineorder.nonveg()  
    @classmethod
    def butternoon(cls):
        user=int(input("enter the order:\n1.butter\n2.paneer\n3.cheese\n7.exit"))
        match user:
            case 1:
                r="butter"
                print(r)
                onlineorder.quanty()
            case 2:
                r="panner"
                onlineorder.quanty()
            case 3:
                r="cheese"
                onlineorder.quanty()
            case 4:
                onlineorder.veg()
            case 5:
                onlineorder.nonveg()
            case 6:
                onlineorder.buger()
            case _:
                return
        return onlineorder.butternoon()
    @classmethod
    def buger(cls):
        user=int(input("enter the order:\n1.nonvegbuger\n2.vegbuger\n6.exit"))
        match user:
            case 1:
                print("nonvegbuger")
                onlineorder.quanty()
            case 2:
                print("vegbuger")
                onlineorder.quanty()
            case 3:
                onlineorder.veg()
            case 4:
                onlineorder.nonveg()
            case 5:
                onlineorder.butternoon()
            case _:
                return
        return onlineorder.buger()
    v={"biryani":100,"rothi":50,"tiffin":50,"meal":100,"chicken":100,"mutton":130,"fish":150,"butter":30,"panner":50,"cheese":30,"nonveg":100,"veg":80}
    def quanty():
        q=int(input("enter no of quanties"))
        print(q)
        print("amount",q*100)
        # print("amount",q*v[r])
onlineorder.login()
# Out:
# mutton
# 1
# amount 100
